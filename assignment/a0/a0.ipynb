# %% [markdown]
# # Assignment 0
#
# This notebook will help verify that you're all set up with the Python packages we'll be using this semester.
#
# **Your task:** just run the cells below, and verify that the output is as expected. If anything looks wrong, weird, or crashes, update your Python installation or contact the course staff. We don't want library issues to get in the way of the real coursework!

# %%
# Version checks
import importlib
def version_check(libname, min_version):
    m = importlib.import_module(libname)
    print "%s version %s is" % (libname, m.__version__),
    print ("OK" if m.__version__ >= min_version 
           else "out-of-date. Please upgrade!")


version_check("numpy", "1.11")
version_check("matplotlib", "1.5")
version_check("pandas", "0.18")
version_check("nltk", "3.2")
version_check("tensorflow", "0.12.1")
# Out:
# numpy version 1.11.3 is OK
# matplotlib version 1.5.3 is OK
# pandas version 0.19.2 is OK
# nltk version 3.2.2 is OK
# tensorflow version 0.12.1 is OK

# %% [markdown]
# ## TensorFlow
#
# We'll be using [TensorFlow](tensorflow.org) to build deep learning models this semester. TensorFlow is a whole programming system in itself, based around the idea of a computation graph and deferred execution. We'll be talking a lot more about it in Assignment 1, but for now you should just test that it loads on your system.
#
# Run the cell below; you should see:
# ```
# Hello, TensorFlow!
# 42
# ```

# %%
import tensorflow as tf

hello = tf.constant("Hello, TensorFlow!")
sess = tf.Session()
print sess.run(hello)

a = tf.constant(10)
b = tf.constant(32)
print sess.run(a+b)

print sess.run(hello + str(a))
# Out:
# Hello, TensorFlow!
# 42
# Hello, TensorFlow!Tensor("Const_1:0", shape=(), dtype=int32)

# %% [markdown]
# (optional) You can also test one of the built-in models. This will train a CNN classifier on the MNIST handwriting dataset. It will generate lots of output, and may take several minutes.

# %%
# This is the same as calling python -m (...) on the command line
# You should see a bunch of output, and a final test error around 0.8%
# It might take a few minutes on a slower machine.
# %run -m tensorflow.models.image.mnist.convolutional
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz
# Initialized!
# Step 0 (epoch 0.00), 11.2 ms
# Minibatch loss: 8.333, learning rate: 0.010000
# Minibatch error: 85.9%
# Validation error: 84.6%
# Step 100 (epoch 0.12), 495.6 ms
# Minibatch loss: 3.237, learning rate: 0.010000
# Minibatch error: 4.7%
# Validation error: 7.4%
# Step 200 (epoch 0.23), 481.9 ms
# Minibatch loss: 3.353, learning rate: 0.010000
# Minibatch error: 10.9%
# Validation error: 4.4%
# Step 300 (epoch 0.35), 474.0 ms
# Minibatch loss: 3.139, learning rate: 0.010000
# Minibatch error: 3.1%
# Validation error: 3.1%
# Step 400 (epoch 0.47), 473.3 ms
# Minibatch loss: 3.233, learning rate: 0.010000
# Minibatch error: 7.8%
# Validation error: 2.9%
# Step 500 (epoch 0.58), 473.6 ms
# Minibatch loss: 3.167, learning rate: 0.010000
# Minibatch error: 6.2%
# Validation error: 2.4%
# Step 600 (epoch 0.70), 471.8 ms
# Minibatch loss: 3.132, learning rate: 0.010000
# Minibatch error: 4.7%
# Validation error: 2.1%
# Step 700 (epoch 0.81), 475.5 ms
# Minibatch loss: 2.982, learning rate: 0.010000
# Minibatch error: 4.7%
# Validation error: 2.3%
# Step 800 (epoch 0.93), 548.6 ms
# Minibatch loss: 3.060, learning rate: 0.010000
# Minibatch error: 7.8%
# Validation error: 2.2%
# Step 900 (epoch 1.05), 509.2 ms
# Minibatch loss: 2.896, learning rate: 0.009500
# Minibatch error: 0.0%
# Validation error: 1.8%
# Step 1000 (epoch 1.16), 508.3 ms
# Minibatch loss: 2.868, learning rate: 0.009500
# Minibatch error: 1.6%
# Validation error: 1.7%
# Step 1100 (epoch 1.28), 507.0 ms
# Minibatch loss: 2.832, learning rate: 0.009500
# Minibatch error: 1.6%
# Validation error: 1.5%
# Step 1200 (epoch 1.40), 505.7 ms
# Minibatch loss: 2.930, learning rate: 0.009500
# Minibatch error: 1.6%
# Validation error: 1.5%
# Step 1300 (epoch 1.51), 520.3 ms
# Minibatch loss: 2.781, learning rate: 0.009500
# Minibatch error: 0.0%
# Validation error: 1.6%
# Step 1400 (epoch 1.63), 525.5 ms
# Minibatch loss: 2.832, learning rate: 0.009500
# Minibatch error: 3.1%
# Validation error: 1.6%
# Step 1500 (epoch 1.75), 530.0 ms
# Minibatch loss: 2.865, learning rate: 0.009500
# Minibatch error: 4.7%
# Validation error: 1.3%
# Step 1600 (epoch 1.86), 528.8 ms
# Minibatch loss: 2.714, learning rate: 0.009500
# Minibatch error: 1.6%
# Validation error: 1.4%
# Step 1700 (epoch 1.98), 527.0 ms
# Minibatch loss: 2.661, learning rate: 0.009500
# Minibatch error: 1.6%
# Validation error: 1.5%
# Step 1800 (epoch 2.09), 526.3 ms
# Minibatch loss: 2.655, learning rate: 0.009025
# Minibatch error: 1.6%
# Validation error: 1.4%
# Step 1900 (epoch 2.21), 527.2 ms
# Minibatch loss: 2.638, learning rate: 0.009025
# Minibatch error: 1.6%
# Validation error: 1.1%
# Step 2000 (epoch 2.33), 525.9 ms
# Minibatch loss: 2.601, learning rate: 0.009025
# Minibatch error: 1.6%
# Validation error: 1.2%
# Step 2100 (epoch 2.44), 526.6 ms
# Minibatch loss: 2.569, learning rate: 0.009025
# Minibatch error: 0.0%
# Validation error: 1.1%
# Step 2200 (epoch 2.56), 528.9 ms
# Minibatch loss: 2.579, learning rate: 0.009025
# Minibatch error: 3.1%
# Validation error: 1.2%
# Step 2300 (epoch 2.68), 529.6 ms
# Minibatch loss: 2.594, learning rate: 0.009025
# Minibatch error: 1.6%
# Validation error: 1.3%
# Step 2400 (epoch 2.79), 530.5 ms
# Minibatch loss: 2.513, learning rate: 0.009025
# Minibatch error: 1.6%
# Validation error: 1.2%
# Step 2500 (epoch 2.91), 531.1 ms
# Minibatch loss: 2.472, learning rate: 0.009025
# Minibatch error: 0.0%
# Validation error: 1.1%
# Step 2600 (epoch 3.03), 531.9 ms
# Minibatch loss: 2.457, learning rate: 0.008574
# Minibatch error: 0.0%
# Validation error: 1.3%
# Step 2700 (epoch 3.14), 544.0 ms
# Minibatch loss: 2.494, learning rate: 0.008574
# Minibatch error: 1.6%
# Validation error: 1.1%
# Step 2800 (epoch 3.26), 527.9 ms
# Minibatch loss: 2.470, learning rate: 0.008574
# Minibatch error: 3.1%
# Validation error: 1.2%
# Step 2900 (epoch 3.37), 527.6 ms
# Minibatch loss: 2.482, learning rate: 0.008574
# Minibatch error: 1.6%
# Validation error: 1.2%
# Step 3000 (epoch 3.49), 529.6 ms
# Minibatch loss: 2.382, learning rate: 0.008574
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 3100 (epoch 3.61), 527.7 ms
# Minibatch loss: 2.383, learning rate: 0.008574
# Minibatch error: 3.1%
# Validation error: 0.9%
# Step 3200 (epoch 3.72), 526.7 ms
# Minibatch loss: 2.333, learning rate: 0.008574
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 3300 (epoch 3.84), 528.8 ms
# Minibatch loss: 2.311, learning rate: 0.008574
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 3400 (epoch 3.96), 534.5 ms
# Minibatch loss: 2.299, learning rate: 0.008574
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 3500 (epoch 4.07), 513.1 ms
# Minibatch loss: 2.284, learning rate: 0.008145
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 3600 (epoch 4.19), 519.7 ms
# Minibatch loss: 2.250, learning rate: 0.008145
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 3700 (epoch 4.31), 528.4 ms
# Minibatch loss: 2.228, learning rate: 0.008145
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 3800 (epoch 4.42), 656.1 ms
# Minibatch loss: 2.217, learning rate: 0.008145
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 3900 (epoch 4.54), 523.0 ms
# Minibatch loss: 2.252, learning rate: 0.008145
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 4000 (epoch 4.65), 485.9 ms
# Minibatch loss: 2.240, learning rate: 0.008145
# Minibatch error: 3.1%
# Validation error: 1.1%
# Step 4100 (epoch 4.77), 484.6 ms
# Minibatch loss: 2.163, learning rate: 0.008145
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 4200 (epoch 4.89), 511.1 ms
# Minibatch loss: 2.171, learning rate: 0.008145
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 4300 (epoch 5.00), 491.5 ms
# Minibatch loss: 2.219, learning rate: 0.007738
# Minibatch error: 3.1%
# Validation error: 0.9%
# Step 4400 (epoch 5.12), 509.4 ms
# Minibatch loss: 2.130, learning rate: 0.007738
# Minibatch error: 0.0%
# Validation error: 1.2%
# Step 4500 (epoch 5.24), 553.8 ms
# Minibatch loss: 2.196, learning rate: 0.007738
# Minibatch error: 6.2%
# Validation error: 1.1%
# Step 4600 (epoch 5.35), 503.6 ms
# Minibatch loss: 2.081, learning rate: 0.007738
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 4700 (epoch 5.47), 560.5 ms
# Minibatch loss: 2.067, learning rate: 0.007738
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 4800 (epoch 5.59), 485.8 ms
# Minibatch loss: 2.065, learning rate: 0.007738
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 4900 (epoch 5.70), 484.8 ms
# Minibatch loss: 2.064, learning rate: 0.007738
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 5000 (epoch 5.82), 484.8 ms
# Minibatch loss: 2.127, learning rate: 0.007738
# Minibatch error: 4.7%
# Validation error: 0.9%
# Step 5100 (epoch 5.93), 547.5 ms
# Minibatch loss: 2.009, learning rate: 0.007738
# Minibatch error: 1.6%
# Validation error: 1.1%
# Step 5200 (epoch 6.05), 495.8 ms
# Minibatch loss: 2.068, learning rate: 0.007351
# Minibatch error: 3.1%
# Validation error: 0.9%
# Step 5300 (epoch 6.17), 493.4 ms
# Minibatch loss: 1.971, learning rate: 0.007351
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 5400 (epoch 6.28), 497.5 ms
# Minibatch loss: 1.962, learning rate: 0.007351
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 5500 (epoch 6.40), 487.6 ms
# Minibatch loss: 1.978, learning rate: 0.007351
# Minibatch error: 3.1%
# Validation error: 1.0%
# Step 5600 (epoch 6.52), 476.7 ms
# Minibatch loss: 1.932, learning rate: 0.007351
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 5700 (epoch 6.63), 472.3 ms
# Minibatch loss: 1.914, learning rate: 0.007351
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 5800 (epoch 6.75), 472.7 ms
# Minibatch loss: 1.899, learning rate: 0.007351
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 5900 (epoch 6.87), 494.1 ms
# Minibatch loss: 1.889, learning rate: 0.007351
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 6000 (epoch 6.98), 551.8 ms
# Minibatch loss: 1.899, learning rate: 0.007351
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 6100 (epoch 7.10), 515.4 ms
# Minibatch loss: 1.865, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 6200 (epoch 7.21), 511.2 ms
# Minibatch loss: 1.843, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 6300 (epoch 7.33), 521.5 ms
# Minibatch loss: 1.839, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 6400 (epoch 7.45), 511.2 ms
# Minibatch loss: 1.834, learning rate: 0.006983
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 6500 (epoch 7.56), 510.3 ms
# Minibatch loss: 1.807, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 6600 (epoch 7.68), 511.1 ms
# Minibatch loss: 1.842, learning rate: 0.006983
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 6700 (epoch 7.80), 509.8 ms
# Minibatch loss: 1.781, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 6800 (epoch 7.91), 511.3 ms
# Minibatch loss: 1.769, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 6900 (epoch 8.03), 509.5 ms
# Minibatch loss: 1.758, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 7000 (epoch 8.15), 508.0 ms
# Minibatch loss: 1.751, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 7100 (epoch 8.26), 508.5 ms
# Minibatch loss: 1.738, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 7200 (epoch 8.38), 509.5 ms
# Minibatch loss: 1.732, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 7300 (epoch 8.49), 509.4 ms
# Minibatch loss: 1.766, learning rate: 0.006634
# Minibatch error: 3.1%
# Validation error: 0.7%
# Step 7400 (epoch 8.61), 508.3 ms
# Minibatch loss: 1.700, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.6%
# Step 7500 (epoch 8.73), 509.9 ms
# Minibatch loss: 1.692, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 7600 (epoch 8.84), 509.2 ms
# Minibatch loss: 1.757, learning rate: 0.006634
# Minibatch error: 1.6%
# Validation error: 0.8%
# Step 7700 (epoch 8.96), 507.1 ms
# Minibatch loss: 1.666, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 7800 (epoch 9.08), 508.7 ms
# Minibatch loss: 1.661, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 7900 (epoch 9.19), 508.3 ms
# Minibatch loss: 1.647, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 8000 (epoch 9.31), 507.5 ms
# Minibatch loss: 1.644, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 8100 (epoch 9.43), 507.8 ms
# Minibatch loss: 1.638, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 8200 (epoch 9.54), 507.7 ms
# Minibatch loss: 1.619, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 8300 (epoch 9.66), 509.6 ms
# Minibatch loss: 1.611, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 8400 (epoch 9.77), 507.9 ms
# Minibatch loss: 1.596, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 8500 (epoch 9.89), 508.7 ms
# Minibatch loss: 1.603, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.9%
# Test error: 0.7%

# %% [markdown]
# ## NLTK
#
# [NLTK](http://www.nltk.org/) is a large compilation of Python NLP packages. It includes implementations of a number of classic NLP models, as well as utilities for working with linguistic data structures, preprocessing text, and managing corpora.
#
# NLTK is included with Anaconda, but the corpora need to be downloaded separately. Be warned that this will take up around 3.2 GB of disk space if you download everything! If this is too much, you can download individual corpora as you need them through the same interface.
#
# Type the following into a Python shell on the command line. It'll open a pop-up UI with the downloader:
#
# ```
# import nltk
# nltk.download()
# ```
#
# Alternatively, you can download individual corpora by name. The cell below will download the famous [Brown corpus](http://www.essex.ac.uk/linguistics/external/clmt/w3c/corpus_ling/content/corpora/list/private/brown/brown.html):

# %%
import nltk
assert(nltk.download("brown"))  # should return True if successful, or already installed
# Out:
# [nltk_data] Downloading package brown to /home/chuck/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %% [markdown]
# Now we can look at a few sentences. Expect to see:
# ```
# The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place .
#
# The jury further said in term-end presentments that the City Executive Committee , which had over-all charge of the election , `` deserves the praise and thanks of the City of Atlanta '' for the manner in which the election was conducted .
# ```

# %%
from nltk.corpus import brown
# Look at the first two sentences
for s in brown.sents()[:3]:
    print " ".join(s)
    print ""
# Out:
# The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place .
#
# The jury further said in term-end presentments that the City Executive Committee , which had over-all charge of the election , `` deserves the praise and thanks of the City of Atlanta '' for the manner in which the election was conducted .
#
# The September-October term jury had been charged by Fulton Superior Court Judge Durwood Pye to investigate reports of possible `` irregularities '' in the hard-fought primary which was won by Mayor-nominate Ivan Allen Jr. .

# %% [markdown]
# NLTK also includes a sample of the [Penn treebank](https://www.cis.upenn.edu/~treebank/), which we'll be using later in the course for parsing and part-of-speech tagging. Here's a sample of sentences, and an example tree. Expect to see:
# ```
# The top money funds are currently yielding well over 9 % .
#
# (S
#   (NP-SBJ (DT The) (JJ top) (NN money) (NNS funds))
#   (VP
#     (VBP are)
#     (ADVP-TMP (RB currently))
#     (VP (VBG yielding) (NP (QP (RB well) (IN over) (CD 9)) (NN %))))
#   (. .))
# ```

# %%
assert(nltk.download("treebank"))  # should return True if successful, or already installed
print ""
from nltk.corpus import treebank
# Look at the parse of a sentence.
# Don't worry about what this means yet!
idx = 45
print " ".join(treebank.sents()[idx])
print ""
print treebank.parsed_sents()[idx]
# Out:
# [nltk_data] Downloading package treebank to /home/chuck/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
#
# The top money funds are currently yielding well over 9 % .
#
# (S
#   (NP-SBJ (DT The) (JJ top) (NN money) (NNS funds))
#   (VP
#     (VBP are)
#     (ADVP-TMP (RB currently))
#     (VP (VBG yielding) (NP (QP (RB well) (IN over) (CD 9)) (NN %))))
#   (. .))

# %% [markdown]
# We can also look at the [Europarl corpus](http://www.statmt.org/europarl/), which consists of *parallel* text - a sentence and its translations to multiple languages. You should see:
# ```
# ENGLISH: Resumption of the session I declare resumed the session of the European Parliament adjourned on Friday 17 December 1999 , and I would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period .
# ```
# and its translation into French and Spanish.

# %%
assert(nltk.download("europarl_raw"))  # should return True if successful, or already installed
print ""
from nltk.corpus import europarl_raw

idx = 0

print "ENGLISH: " + " ".join(europarl_raw.english.sents()[idx])
print ""
print "FRENCH: " + " ".join(europarl_raw.french.sents()[idx])
print ""
print "SPANISH: " + " ".join(europarl_raw.spanish.sents()[idx])
# Out:
# [nltk_data] Downloading package europarl_raw to
# [nltk_data]     /home/chuck/nltk_data...
# [nltk_data]   Unzipping corpora/europarl_raw.zip.
#
# ENGLISH: Resumption of the session I declare resumed the session of the European Parliament adjourned on Friday 17 December 1999 , and I would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period .
#
# FRENCH: Reprise de la session Je déclare reprise la session du Parlement européen qui avait été interrompue le vendredi 17 décembre dernier et je vous renouvelle tous mes vux en espérant que vous avez passé de bonnes vacances .
#
# SPANISH: Reanudación del período de sesiones Declaro reanudado el período de sesiones del Parlamento Europeo , interrumpido el viernes 17 de diciembre pasado , y reitero a Sus Señorías mi deseo de que hayan tenido unas buenas vacaciones .
